# %%
import pandas as pd
import numpy as np
import nelpy as nel
import math

# %%
filename = '/Users/jinjiang-macair/Desktop/DLC/streakertest1.h5'
pd.read_hdf(filename)
# Out:
# scorer    DLC_resnet50_ControlSep27shuffle1_121000                         \
# bodyparts                                    snout
# coords                                           x           y likelihood
# 0                                        95.128639    3.427732   0.000073
# 1                                        95.093483    3.416033   0.000084
# 2                                        95.091095    3.415520   0.000084
# 3                                       129.494431  401.813446   0.000347
# 4                                       129.496948  401.950684   0.000158
# ...                                            ...         ...        ...
# 19925                                   128.220108  403.991699   0.993865
# 19926                                   128.258774  404.035522   0.993238
# 19927                                   128.357712  404.015442   0.992822
# 19928                                   128.328415  404.010925   0.992940
# 19929                                   128.384872  404.011475   0.993293
#
# scorer                                                                \
# bodyparts     leftEar                           rightEar
# coords              x           y likelihood           x           y
# 0           23.494085  432.386169   0.000039  493.791809  124.754173
# 1          495.275543  124.651344   0.000044  493.701324  124.674858
# 2          495.284149  124.661774   0.000046  493.684845  124.662994
# 3          495.321198  124.626175   0.000053  493.650696  124.732384
# 4          495.284332  124.641747   0.000051  493.706848  124.778831
# ...               ...         ...        ...         ...         ...
# 19925      129.610397  417.081177   0.985454  137.101929  406.160828
# 19926      129.703293  417.116669   0.983189  137.150360  406.063782
# 19927      129.753723  417.113892   0.979698  137.179489  406.000610
# 19928      129.717346  417.151428   0.980744  137.175522  406.003937
# 19929      129.641968  417.190552   0.979334  137.188080  406.006073
#
# scorer
# bodyparts                   tail
# coords    likelihood           x           y likelihood
# 0           0.000040  498.717834  124.947479   0.000418
# 1           0.000045  498.596222  124.817734   0.001196
# 2           0.000047  498.548889  124.839355   0.001492
# 3           0.000054  498.606934  124.783524   0.002259
# 4           0.000052  498.630127  124.750565   0.001329
# ...              ...         ...         ...        ...
# 19925       0.998475  205.827972  421.467865   0.999601
# 19926       0.998379  205.801178  421.483398   0.999635
# 19927       0.998237  205.795761  421.479858   0.999631
# 19928       0.998272  205.797394  421.476685   0.999625
# 19929       0.998050  205.805237  421.478668   0.999623
#
# [19930 rows x 12 columns]

# %%
h5filename = filename
position_data = pd.read_hdf(h5filename)
snout = position_data.get_values()[:,0:2]
snoutprob = position_data.get_values()[:,2]
leftEar = position_data.get_values()[:,3:5]
leftprob = position_data.get_values()[:,5]
rightEar = position_data.get_values()[:,6:8]
rightprob = position_data.get_values()[:,8]
tail = position_data.get_values()[:,9:11]
tailprob = position_data.get_values()[:,11]
#leftASA = nel.AnalogSignalArray(left.T,fs=60)
#leftASA = leftASA.smooth(sigma=0.05)

#rightASA = nel.AnalogSignalArray(right.T,fs=60)
#rightASA = rightASA.smooth(sigma=0.05)

#snoutASA = nel.AnalogSignalArray(snout.T,fs=60)
#snoutASA = snoutASA.smooth(sigma=0.05)

#midASA = nel.AnalogSignalArray(mid.T,fs=60)
#midASA = midASA.smooth(sigma=0.05)

#backASA = nel.AnalogSignalArray(back.T,fs=60)
#backASA = backASA.smooth(sigma=0.05)

#bodyASA = nel.AnalogSignalArray(body.T,fs=60)
#backASA = bodyASA.smooth(sigma=0.05)
#ledASA = nel.AnalogSignalArray(led.T,fs=60)
#ledASA = ledASA.smooth(sigma=0.01)
#tailASA = nel.AnalogSignalArray(tail.T,fs=60)
#tailASA = tailASA.smooth(sigma=0.01)

#led[1515,0:2]

#left = leftASA.data.T
#right = rightASA.data.T
#snout = snoutASA.data.T
#mid = midASA.data.T
#back = backASA.data.T
#body = bodyASA.data.T
#led = ledASA.data.T
#tail = tailASA.data.T
# Out:
# /Users/jinjiang-macair/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
# /Users/jinjiang-macair/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
# /Users/jinjiang-macair/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
# /Users/jinjiang-macair/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
# /Users/jinjiang-macair/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
# /Users/jinjiang-macair/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
# /Users/jinjiang-macair/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
# /Users/jinjiang-macair/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.

# %%
leftEar.shape
# Out:
# (19930, 2)

# %%
#!/usr/bin/env python

'''
Multithreaded video processing sample.
Usage:
   video_threaded.py {<video device number>|<video file name>}
   Shows how python threading capabilities can be used
   to organize parallel captured frame processing pipeline
   for smoother playback.
Keyboard shortcuts:
   ESC - exit
   space - switch between multi and single threaded processing
'''


# Python 2/3 compatibility
from __future__ import print_function

import numpy as np
import cv2 as cv

from multiprocessing.pool import ThreadPool
from collections import deque

from common import clock, draw_str, StatValue
import video

NUMFRAMES = 1525
rad = 12 #this is how big the circles are that represent the object. You will need to left click on the objects when the video starts.
big = False
obj1posSet = set()
obj2posSet = set()
#bigobj1posSet = set()
obj1interaction_frames = 0
obj2interaction_frames = 0
obj1indicator = int(20),int(20) #where the interaction indicator is
obj2indicator = int(70),int(20)

class DummyTask:
    def __init__(self, data):
        self.data = data
    def ready(self):
        return True
    def get(self):
        return self.data

def main():
    import sys

    try:
        fn = filename
    except:
        fn = 0
    cap = video.create_capture(fn)

    
    def objectBorder(event, x, y, flags, param):
       global obj1posSet, obj2posSet, big
       if event == cv.EVENT_LBUTTONDBLCLK:
            bigobj1posSet.add((x,y))
       if event == cv.EVENT_LBUTTONDOWN:
            obj1posSet.add((x, y))
       if event == cv.EVENT_RBUTTONDOWN:
            obj2posSet.add((x, y))
       
    #below code is for dragging mouse to label object borders
            #drawing = True
       #elif event == cv.EVENT_MOUSEMOVE:
           # if drawing == True:
                #posSet.add((x, y))
                #cv.circle(frame,(x,y),rad,(0,0,255),2)
       #elif event == cv.EVENT_LBUTTONUP:
            #drawing = False
        
    def distance(point1, point2):
        x_dist = abs(point1[0] - point2[0])
        y_dist = abs(point1[1] - point2[1])
        return math.hypot(x_dist,y_dist)
        
    def process_frame(frame, t0, frame_num):
        # some intensive computation...
#         frame = cv.medianBlur(frame, 19)
#         frame = cv.medianBlur(frame, 19)
        global head_dir
    
        xr = rightEar[frame_num][0]
        yr = rightEar[frame_num][1]
        xl = leftEar[frame_num][0]
        yl = leftEar[frame_num][1]
        xmid = (xl+xr)/2.0
        ymid = (yl+yr)/2.0
        head_mid = int(np.round(xmid)),int(np.round(ymid)) #define middle of the head as midpoint between left and right corners of implant
        tailx = tail[frame_num][0]
        taily = tail[frame_num][1]
        
        gap = 10.0 #how far in front/behind of head mid the point representing head direction will be.
        slope = ((yr-yl)/(xr-xl)) #slope between left and right corners of implant
        negx = 0
        posx = 0
        negy = 0
        posy = 0
        head_dir = 0
        
        dy = math.sqrt(gap**2/(1+slope**2)) #use pythagorean theorem to find x and y displacement
        dx = -slope*dy
        posx = xmid + dx
        posy = ymid + dy
        negx = xmid - dx
        negy = ymid - dy
           
        poshead_dir = posx, posy #two solutions to square root
        neghead_dir = negx, negy
        
        
        if snoutprob[frame_num] > 0.95: #if the snout reading is accurate, use that as head dir
            head_dir = snout[frame_num]
        elif rightprob[frame_num] > 0.95 and leftprob[frame_num] > 0.95:
            if math.sqrt((posx-tailx)**2+(posy-taily)**2) > math.sqrt((negx-tailx)**2+(negy-taily)**2): #otherwise use midpoint perpendicular to slope btwn implant corners
                head_dir = poshead_dir
            else:
                head_dir = neghead_dir
        else:
            head_dir = 0,0
        drawTailCircleHere = int(np.round(tail[frame_num][0])),int(np.round(tail[frame_num][1]))
        drawleftEarCircleHere = int(np.round(leftEar[frame_num][0])),int(np.round(leftEar[frame_num][1]))
        drawrightEarCircleHere = int(np.round(rightEar[frame_num][0])),int(np.round(rightEar[frame_num][1]))
        drawsnoutCircleHere = int(np.round(snout[frame_num][0])),int(np.round(snout[frame_num][1]))
        
        drawhead_directionCircleHere = int(np.round(head_dir[0])), int(np.round(head_dir[1]))
                                 
        #frame = cv.circle(frame, drawledCircleHere, 4, (255, 100, 0), 2)
        #frame = cv.circle(frame, drawTailCircleHere, 4, (0, 100, 200), 2)
        #frame = cv.circle(frame, drawBodyCircleHere, 4, (0, 100, 200), 2)
        #frame = cv.circle(frame, drawmidCircleHere, 4, (50, 50, 0), 2)
        #frame = cv.circle(frame, drawbackCircleHere, 4, (0, 50, 75), 2)
        #frame = cv.circle(frame, drawleftCircleHere, 4, (0, 255, 255), 2)
        #frame = cv.circle(frame, drawrightCircleHere, 4, (100, 100, 100), 2)
        #frame = cv.circle(frame, head_mid, 4, (200,200,100), 2)
        #frame = cv.circle(frame, drawhead_directionCircleHere, 4, (0,255,0), 2)
        frame = cv.circle(frame, drawsnoutCircleHere, 4, (0, 20, 255), 2)
        
        for point in obj1posSet:
            drawPointHere = int(np.round(point[0])),int(np.round(point[1])) #make the labeled border points into integers
            cv.circle(frame, drawPointHere, rad, (255,255,255), 1) #define a circle at each point for visualization purposes
            
            if distance(head_dir,point) < rad: #if the head direction point is close enough to the labeled point, it's interacting
                global obj1interaction_frames #need global because otherwise it won't save between frames
                obj1interaction_frames += 1
                cv.circle(frame, obj1indicator, 20, (0,255,0), -1) #make the indicator light green
                break #if interacting with one point, then don't need to check the rest
                
            else:
                cv.circle(frame, obj1indicator, 20, (0,0,255), -1) #if not interacting, make indicator light red
        #cv.imwrite("images/%04d.tiff"%frame_num,frame)
        for point in obj2posSet:
            drawPointHere = int(np.round(point[0])),int(np.round(point[1])) 
            cv.circle(frame, drawPointHere, rad, (255,255,255), 1) 
            
            if distance(head_dir,point) < rad:
                global obj2interaction_frames
                obj1interaction_frames += 1
                cv.circle(frame, obj2indicator, 20, (0,255,0), -1) #make the indicator light green
                break #if interacting with one point, then don't need to check the rest
                
            else:
                cv.circle(frame, obj2indicator, 20, (0,0,255), -1) #if not interacting, make indicator light red
        #cv.imwrite("images/%04d.tiff"%frame_num,frame)
        return frame, t0
         
    threadn = cv.getNumberOfCPUs()
    pool = ThreadPool(processes = threadn)
    pending = deque()
    
    threaded_mode = True

    latency = StatValue()
    frame_interval = StatValue()
    last_frame_time = clock()
    framenum = 0
    
    while framenum < len(leftEar):
        while len(pending) > 0 and pending[0].ready():
            res, t0 = pending.popleft().get()
            latency.update(clock() - t0)
            draw_str(res, (20, 20), "threaded      :  " + str(threaded_mode))
            draw_str(res, (20, 40), "latency        :  %.1f ms" % (latency.value*1000))
            draw_str(res, (20, 60), "frame interval :  %.1f ms" % (frame_interval.value*1000))
            cv.namedWindow('test',cv.WINDOW_AUTOSIZE)
            #cv.moveWindow('test',0,0)
            cv.imshow('test',res)
            #cv.imshow('threaded video', res)
            
        if len(pending) < threadn:
            
            cv.setMouseCallback('test', objectBorder)
            _ret, frame = cap.read()
            framenum += 1
            t = clock()
            frame_interval.update(t - last_frame_time)
            last_frame_time = t
            
            if threaded_mode:
                task = pool.apply_async(process_frame, (frame.copy(), t,framenum))
            else:
                task = DummyTask(process_frame(frame, t,framenum))
            pending.append(task)
            
        ch = cv.waitKey(1)
        
        if ch == ord(' '):
            threaded_mode = not threaded_mode
        if ch == 27:
            obj1posSet.clear()
            obj2posSet.clear()
            break
            
        print(obj1interaction_frames)
        print(obj2interaction_frames)
        print(obj1posSet)
        #print(bigobj1posSet)
        print(obj2posSet)
        
    print('Done')
    print("Seconds spent interacting with object 1:", obj1interaction_frames/60)
    print("Seconds spent interacting with object 2:", obj2interaction_frames/60)

if __name__ == '__main__':
    time = clock()
    print(__doc__)
    filename = "/Users/jinjiang-macair/Desktop/DLC/NonImplantedControl/Streaker/Day1/streakertest1.mp4"
    #headcoords_on = np.load("demo_headcoords_on.npz")['headcoords_on']
    main()
    cv.destroyAllWindows()
    print("This took %6.2f seconds"%(clock() - time))
# Out:
# Multithreaded video processing sample.
# Usage:
#    video_threaded.py {<video device number>|<video file name>}
#    Shows how python threading capabilities can be used
#    to organize parallel captured frame processing pipeline
#    for smoother playback.
# Keyboard shortcuts:
#    ESC - exit
#    space - switch between multi and single threaded processing
#
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# set()
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 367), (413, 351), (414, 375)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# {(227, 369), (219, 346), (419, 364), (208, 355), (413, 351), (414, 375), (406, 378), (225, 357), (229, 372), (227, 339), (413, 367), (395, 364)}
# set()
# 0
# 0
# ...
# set()
# 680
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 681
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 682
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 683
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 684
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 685
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 686
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 687
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 688
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 689
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 690
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 691
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 692
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 693
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 694
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 695
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 696
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 697
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 698
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 699
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 700
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# 701
# 0
# {(227, 369), (219, 346), (419, 364), (233, 354), (208, 355), (413, 351), (414, 375), (406, 378), (405, 355), (419, 373), (225, 357), (229, 372), (217, 366), (227, 339), (418, 344), (413, 367), (395, 364), (417, 383)}
# set()
# Done
# Seconds spent interacting with object 1: 11.683333333333334
# Seconds spent interacting with object 2: 0.0
# This took  77.50 seconds

# %%
print("interaction frames: " interaction_frames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6822a0b67f1c> in <module>
# ----> 1 print(poshead_dir)
#
# NameError: name 'poshead_dir' is not defined
